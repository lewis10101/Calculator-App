# %% [markdown]
# <a href="https://colab.research.google.com/github/lewis10101/Calculator-App/blob/main/calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hi")
for i in range(5):
  print(i)
# Out:
# Hi
# 0
# 1
# 2
# 3
# 4
